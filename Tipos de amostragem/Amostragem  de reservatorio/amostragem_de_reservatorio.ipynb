# %%
import pandas as pd
import numpy as np
import random

# %%
dataset = pd.read_csv('/content/drive/MyDrive/census.csv')

# %%
stream = []
for i in range(len(dataset)):
  stream.append(i)

# %%
def amostragem_reservatorio(dataset, amostras):
  stream = []
  for i in range(len(dataset)):
    stream.append(i)

  i = 0
  tamanho = len(dataset)
  
  reservatorio = [0] * amostras
  for i in range(amostras):
    reservatorio[i] = stream[i]

  while i < tamanho:
    j = random.randrange(i + 1)
    if j < amostras:
      reservatorio[j] = stream[i]
      i += 1

  return dataset.iloc[reservatorio]

df_amostragem_reservatorio = amostragem_reservatorio(dataset, 100)
df_amostragem_reservatorio.shape
# Out:
# (100, 15)

# %%
df_amostragem_reservatorio.head()
# Out:
#        age          workclass  final-weight      education  education-num  \
# 32548   65   Self-emp-not-inc         99359    Prof-school             15
# 32522   58            Private        147707           11th              7
# 32464   45       Self-emp-inc        173664      Bachelors             13
# 32317   63                  ?        126540   Some-college             10
# 32545   39          Local-gov        111499     Assoc-acdm             12
#
#             marital-status        occupation    relationship    race      sex  \
# 32548        Never-married    Prof-specialty   Not-in-family   White     Male
# 32522   Married-civ-spouse             Sales         Husband   White     Male
# 32464   Married-civ-spouse   Exec-managerial         Husband   White     Male
# 32317             Divorced                 ?   Not-in-family   White   Female
# 32545   Married-civ-spouse      Adm-clerical            Wife   White   Female
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# 32548          1086             0             60   United-States   <=50K
# 32522             0             0             40   United-States   <=50K
# 32464             0             0             45   United-States    >50K
# 32317             0             0              5   United-States   <=50K
# 32545             0             0             20   United-States    >50K
